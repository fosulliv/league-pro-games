# %%
import numpy as np
import pandas as pd
import os
import requests
import bs4
import json
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, TransformerMixin

from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.base import BaseEstimator

# %%
# %store -r games

# %%
# Out:
#           blue_adc   blue_ban1 blue_ban2     blue_ban3 blue_ban4 blue_ban5  \
# 0             Jhin    Pantheon     Akali         Leona     Rakan      Lulu
# 1           Samira  Blitzcrank      Ornn        Lillia      Azir      Shen
# 2           Ezreal      Samira    Aatrox         Galio     Leona    No ban
# 3     Miss Fortune     Karthus    Syndra  Twisted Fate      Lulu      Ornn
# 4             Jhin       Akali      Ekko        Lillia      Fizz    Thresh
# ...            ...         ...       ...           ...       ...       ...
# 3533      Tristana       Varus    Thresh      Renekton   Alistar  Nautilus
# 3534        Ezreal    Nocturne   Lee Sin         Varus   Kalista    Irelia
# 3535        Ezreal      Lucian  Renekton         Varus     Akali    Rumble
# 3536      Tristana       Varus      Gwen       Lee Sin     Kaisa  Nautilus
# 3537        Ezreal       Senna    Lucian          Udyr    Viktor   Nidalee
#
#       blue_jg blue_mid  blue_sup    blue_team  ... red_ban3    red_ban4  \
# 0     Nidalee  LeBlanc      Bard           CG  ...   Lucian    Nautilus
# 1         Zac  Orianna  Nautilus  For The Win  ...   Aatrox    Renekton
# 2     Hecarim     Ahri     Taric  For The Win  ...     Ornn  Blitzcrank
# 3     Hecarim   Lucian  Nautilus         OFF7  ...   Lillia    Vladimir
# 4     Kindred   Syndra     Leona         OFF7  ...   Graves        Lulu
# ...       ...      ...       ...          ...  ...      ...         ...
# 3533     Udyr      Zoe     Leona           GG  ...     Gwen     Orianna
# 3534     Udyr    Karma     Leona  100 Thieves  ...     Gwen      Syndra
# 3535    Viego    Sylas      Sett     FlyQuest  ...   Thresh       Karma
# 3536     Udyr   Viktor     Leona          TSM  ...    Viego      Ezreal
# 3537   Rumble     Sett     Leona     Dignitas  ...     Gwen    Nocturne
#
#      red_ban5    red_jg   red_mid   red_sup     red_team      red_top red_win  \
# 0      Thresh   Hecarim  Kassadin   Alistar        eSuba         Ornn   False
# 1        Sett    Graves    Syndra    Thresh    GTZ Bulls     Vladimir    True
# 2        Bard    Gragas      Ryze  Nautilus    GTZ Bulls  Mordekaiser   False
# 3      Kennen    Graves   Orianna     Leona  Boavista FC         Shen    True
# 4     Orianna    RekSai      Sett  Pantheon  Boavista FC        Kayle   False
# ...       ...       ...       ...       ...          ...          ...     ...
# 3533    Karma    Rumble     Viego      Sett       Cloud9      Lee Sin   False
# 3534  Orianna    Rumble     Jayce  Nautilus    Immortals         Sett    True
# 3535    Braum   Karthus   Lee Sin     Leona          CLG    Gangplank   False
# 3536    Senna    Rumble    Lucian    Thresh           EG       Kennen   False
# 3537    Viego  Xin Zhao     Sylas    Thresh     FlyQuest      Lee Sin   False
#
#                                tournament
# 0     Hitpoint Masters Winter League 2020
# 1                  LPLOL Grand Final 2020
# 2                  LPLOL Grand Final 2020
# 3                  LPLOL Grand Final 2020
# 4                  LPLOL Grand Final 2020
# ...                                   ...
# 3533                      LCS Summer 2021
# 3534                      LCS Summer 2021
# 3535                      LCS Summer 2021
# 3536                      LCS Summer 2021
# 3537                      LCS Summer 2021
#
# [3538 rows x 25 columns]
