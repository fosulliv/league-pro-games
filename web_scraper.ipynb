# %%
import numpy as np
import pandas as pd
import os
import requests
import bs4
import json

# %%
url = 'https://gol.gg/game/stats/{}/page-game/'
first = 27397
last = 31388
htt = requests.get(url.format(first)).content
soup = bs4.BeautifulSoup(htt)
champs = soup.find_all('img', attrs={'class': 'champion_icon_medium rounded-circle'})
blue = champs[5:10]
red = champs[15:20]
blue = [i['alt'] for i in blue]
red = [i['alt'] for i in red]
blue_bans = champs[:5]
blue_bans = [i['alt'] for i in blue_bans]
red_bans = champs[10:15]
red_bans = [i['alt'] for i in red_bans]
red_bans
# Out:
# ['Graves', 'Kindred', 'Lucian', 'Nautilus', 'Thresh']

# %%
games = {'blue_top': blue[0], 'blue_jg': blue[1], 'blue_mid': blue[2], 'blue_adc': blue[3],
         'blue_sup': blue[4], 'red_top': red[0], 'red_jg': red[1], 'red_mid': red[2], 'red_adc': red[3],
         'red_sup': red[4], 'blue_ban1': blue_bans[0], 'blue_ban2': blue_bans[1], 'blue_ban3': blue_bans[2],
        'blue_ban4': blue_bans[3], 'blue_ban5': blue_bans[4], 'red_ban1': red_bans[0], 'red_ban2': red_bans[1],
        'red_ban3': red_bans[2], 'red_ban4': red_bans[3], 'red_ban5': red_bans[4]}

blue_win = 'WIN' in soup.find('div', attrs={'class': 'col-12 blue-line-header'}).text
red_win = 'WIN' in soup.find('div', attrs={'class': 'col-12 red-line-header'}).text
games['blue_win'] = blue_win
games['red_win'] = red_win

teams = soup.find('div', attrs={'class': 'col-12 mt-4'}).find('h1').text.split(' vs ')
blue_team = teams[0]
red_team = teams[1]
tournament = soup.find('div', attrs={'class': 'col-12 col-sm-7'}).text.split('(')[0].strip()

games['blue_team'] = blue_team
games['red_team'] = red_team
games['tournament'] = tournament

# %%
df
# Out:
#          blue_top  blue_jg blue_mid      blue_adc  blue_sup      red_top  \
# 0         Camille  Nidalee  LeBlanc          Jhin      Bard         Ornn
# 1        Volibear      Zac  Orianna        Samira  Nautilus     Vladimir
# 2            Shen  Hecarim     Ahri        Ezreal     Taric  Mordekaiser
# 3     Mordekaiser  Hecarim   Lucian  Miss Fortune  Nautilus         Shen
# 4          Maokai  Kindred   Syndra          Jhin     Leona        Kayle
# ...           ...      ...      ...           ...       ...          ...
# 3872         Gnar     Udyr      Zoe      Tristana     Leona      Lee Sin
# 3873       Wukong     Udyr    Karma        Ezreal     Leona         Sett
# 3874         Gwen    Viego    Sylas        Ezreal      Sett    Gangplank
# 3875         Gnar     Udyr   Viktor      Tristana     Leona       Kennen
# 3876        Jayce   Rumble     Sett        Ezreal     Leona      Lee Sin
#
#         red_jg   red_mid   red_adc   red_sup  ...  red_ban1  red_ban2  \
# 0      Hecarim  Kassadin      Ashe   Alistar  ...    Graves   Kindred
# 1       Graves    Syndra      Jhin    Thresh  ...     Galio    Lucian
# 2       Gragas      Ryze      Yone  Nautilus  ...    Lucian    Lillia
# 3       Graves   Orianna      Jhin     Leona  ...     Akali      Ekko
# 4       RekSai      Sett    Samira  Pantheon  ...   Karthus    Lucian
# ...        ...       ...       ...       ...  ...       ...       ...
# 3872    Rumble     Viego     Kaisa      Sett  ...     Senna    Lucian
# 3873    Rumble     Jayce  Tristana  Nautilus  ...  Renekton     Senna
# 3874   Karthus   Lee Sin     Kaisa     Leona  ...     Senna      Udyr
# 3875    Rumble    Lucian      Jinx    Thresh  ...  Nocturne  Renekton
# 3876  Xin Zhao     Sylas     Varus    Thresh  ...   Kalista  Renekton
#
#      red_ban3    red_ban4 red_ban5 blue_win red_win    blue_team     red_team  \
# 0      Lucian    Nautilus   Thresh     True   False           CG        eSuba
# 1      Aatrox    Renekton     Sett    False    True  For The Win    GTZ Bulls
# 2        Ornn  Blitzcrank     Bard     True   False  For The Win    GTZ Bulls
# 3      Lillia    Vladimir   Kennen    False    True         OFF7  Boavista FC
# 4      Graves        Lulu  Orianna     True   False         OFF7  Boavista FC
# ...       ...         ...      ...      ...     ...          ...          ...
# 3872     Gwen     Orianna    Karma     True   False           GG       Cloud9
# 3873     Gwen      Syndra  Orianna    False    True  100 Thieves    Immortals
# 3874   Thresh       Karma    Braum     True   False     FlyQuest          CLG
# 3875    Viego      Ezreal    Senna     True   False          TSM           EG
# 3876     Gwen    Nocturne    Viego     True   False     Dignitas     FlyQuest
#
#                                tournament
# 0     Hitpoint Masters Winter League 2020
# 1                  LPLOL Grand Final 2020
# 2                  LPLOL Grand Final 2020
# 3                  LPLOL Grand Final 2020
# 4                  LPLOL Grand Final 2020
# ...                                   ...
# 3872                      LCS Summer 2021
# 3873                      LCS Summer 2021
# 3874                      LCS Summer 2021
# 3875                      LCS Summer 2021
# 3876                      LCS Summer 2021
#
# [3877 rows x 25 columns]

# %% [markdown]
# for i in range(first+len(df), last+1):
#     response = requests.get(url.format(i))
#     if response.ok:
#         soup = bs4.BeautifulSoup(response.content)
#         champs = soup.find_all('img', attrs={'class': 'champion_icon_medium rounded-circle'})
#         blue = champs[5:10]
#         red = champs[15:20]
#         blue = [i['alt'] for i in blue]
#         red = [i['alt'] for i in red]
#         blue_bans = champs[:5]
#         blue_bans = [i['alt'] for i in blue_bans]
#         red_bans = champs[10:15]
#         red_bans = [i['alt'] for i in red_bans]
#         try:
#             games = {'blue_top': blue[0], 'blue_jg': blue[1], 'blue_mid': blue[2], 'blue_adc': blue[3],
#                  'blue_sup': blue[4], 'red_top': red[0], 'red_jg': red[1], 'red_mid': red[2], 'red_adc': red[3],
#                  'red_sup': red[4], 'blue_ban1': blue_bans[0], 'blue_ban2': blue_bans[1], 'blue_ban3': blue_bans[2],
#                 'blue_ban4': blue_bans[3], 'blue_ban5': blue_bans[4], 'red_ban1': red_bans[0], 'red_ban2': red_bans[1],
#                 'red_ban3': red_bans[2], 'red_ban4': red_bans[3], 'red_ban5': red_bans[4]}
#         except IndexError:
#             continue
#
#         blue_win = 'WIN' in soup.find('div', attrs={'class': 'col-12 blue-line-header'}).text
#         red_win = 'WIN' in soup.find('div', attrs={'class': 'col-12 red-line-header'}).text
#         games['blue_win'] = blue_win
#         games['red_win'] = red_win
#
#         teams = soup.find('div', attrs={'class': 'col-12 mt-4'}).find('h1').text.split(' vs ')
#         blue_team = teams[0]
#         red_team = teams[1]
#         tournament = soup.find('div', attrs={'class': 'col-12 col-sm-7'}).text.split('(')[0].strip()
#
#         games['blue_team'] = blue_team
#         games['red_team'] = red_team
#         games['tournament'] = tournament
#         df = df.append(games, ignore_index=True)
#     else:
#         continue
#
# df['red_win'] = df['red_win'].astype(bool)
# df['blue_win'] = df['blue_win'].astype(bool)

# %%
df
# Out:
#          blue_top  blue_jg blue_mid      blue_adc  blue_sup      red_top  \
# 0         Camille  Nidalee  LeBlanc          Jhin      Bard         Ornn
# 1        Volibear      Zac  Orianna        Samira  Nautilus     Vladimir
# 2            Shen  Hecarim     Ahri        Ezreal     Taric  Mordekaiser
# 3     Mordekaiser  Hecarim   Lucian  Miss Fortune  Nautilus         Shen
# 4          Maokai  Kindred   Syndra          Jhin     Leona        Kayle
# ...           ...      ...      ...           ...       ...          ...
# 3872         Gnar     Udyr      Zoe      Tristana     Leona      Lee Sin
# 3873       Wukong     Udyr    Karma        Ezreal     Leona         Sett
# 3874         Gwen    Viego    Sylas        Ezreal      Sett    Gangplank
# 3875         Gnar     Udyr   Viktor      Tristana     Leona       Kennen
# 3876        Jayce   Rumble     Sett        Ezreal     Leona      Lee Sin
#
#         red_jg   red_mid   red_adc   red_sup  ...  red_ban1  red_ban2  \
# 0      Hecarim  Kassadin      Ashe   Alistar  ...    Graves   Kindred
# 1       Graves    Syndra      Jhin    Thresh  ...     Galio    Lucian
# 2       Gragas      Ryze      Yone  Nautilus  ...    Lucian    Lillia
# 3       Graves   Orianna      Jhin     Leona  ...     Akali      Ekko
# 4       RekSai      Sett    Samira  Pantheon  ...   Karthus    Lucian
# ...        ...       ...       ...       ...  ...       ...       ...
# 3872    Rumble     Viego     Kaisa      Sett  ...     Senna    Lucian
# 3873    Rumble     Jayce  Tristana  Nautilus  ...  Renekton     Senna
# 3874   Karthus   Lee Sin     Kaisa     Leona  ...     Senna      Udyr
# 3875    Rumble    Lucian      Jinx    Thresh  ...  Nocturne  Renekton
# 3876  Xin Zhao     Sylas     Varus    Thresh  ...   Kalista  Renekton
#
#      red_ban3    red_ban4 red_ban5 blue_win red_win    blue_team     red_team  \
# 0      Lucian    Nautilus   Thresh     True   False           CG        eSuba
# 1      Aatrox    Renekton     Sett    False    True  For The Win    GTZ Bulls
# 2        Ornn  Blitzcrank     Bard     True   False  For The Win    GTZ Bulls
# 3      Lillia    Vladimir   Kennen    False    True         OFF7  Boavista FC
# 4      Graves        Lulu  Orianna     True   False         OFF7  Boavista FC
# ...       ...         ...      ...      ...     ...          ...          ...
# 3872     Gwen     Orianna    Karma     True   False           GG       Cloud9
# 3873     Gwen      Syndra  Orianna    False    True  100 Thieves    Immortals
# 3874   Thresh       Karma    Braum     True   False     FlyQuest          CLG
# 3875    Viego      Ezreal    Senna     True   False          TSM           EG
# 3876     Gwen    Nocturne    Viego     True   False     Dignitas     FlyQuest
#
#                                tournament
# 0     Hitpoint Masters Winter League 2020
# 1                  LPLOL Grand Final 2020
# 2                  LPLOL Grand Final 2020
# 3                  LPLOL Grand Final 2020
# 4                  LPLOL Grand Final 2020
# ...                                   ...
# 3872                      LCS Summer 2021
# 3873                      LCS Summer 2021
# 3874                      LCS Summer 2021
# 3875                      LCS Summer 2021
# 3876                      LCS Summer 2021
#
# [3877 rows x 25 columns]
