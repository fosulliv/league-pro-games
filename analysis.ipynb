# %%
import numpy as np
import pandas as pd
import os
import requests
import bs4
import json
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, TransformerMixin

from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import QuantileTransformer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.base import BaseEstimator

# %%
# %store -r games

# %%
X = games.drop(['blue_win', 'red_win'], axis=1)
y = games.blue_win
X.columns
# Out:
# Index(['blue_adc', 'blue_ban1', 'blue_ban2', 'blue_ban3', 'blue_ban4',
#        'blue_ban5', 'blue_jg', 'blue_mid', 'blue_sup', 'blue_team', 'blue_top',
#        'red_adc', 'red_ban1', 'red_ban2', 'red_ban3', 'red_ban4', 'red_ban5',
#        'red_jg', 'red_mid', 'red_sup', 'red_team', 'red_top', 'tournament'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)
preproc = ColumnTransformer(transformers=[('ohe', OrdinalEncoder('use_encoded_value'), ['blue_adc', 'blue_ban1', 'blue_ban2', 'blue_ban3',
                                                                                          'blue_ban4', 'blue_ban5', 'blue_jg', 'blue_mid', 'blue_sup',
                                                                                          'blue_team', 'blue_top', 'red_adc', 'red_ban1', 'red_ban2',
                                                                                          'red_ban3', 'red_ban4', 'red_ban5', 'red_jg', 'red_mid',
                                                                                          'red_sup', 'red_team', 'red_top', 'tournament'])])
pl = Pipeline(steps=[('preprocessing', preproc), ('classifier', DecisionTreeClassifier())])
pl.fit(X_train, y_train)
# Out:
# /Users/flynnosullivan/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:67: FutureWarning: Pass categories=use_encoded_value as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn("Pass {} as keyword args. From version 0.25 "
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-65d51f92c0d4> in <module>
#       6                                                                                           'red_sup', 'red_team', 'red_top', 'tournament'])])
#       7 pl = Pipeline(steps=[('preprocessing', preproc), ('classifier', DecisionTreeClassifier())])
# ----> 8 pl.fit(X_train, y_train)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     328         """
#     329         fit_params_steps = self._check_fit_params(**fit_params)
# ...

# %%
pl.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-285434ded531> in <module>
# ----> 1 pl.score(X_test, y_test)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     117
#     118         # lambda, but not partial, allows help() to work with update_wrapper
# --> 119         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     120         # update the docstring of the returned function
#     121         update_wrapper(out, self.fn)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/pipeline.py in score(self, X, y, sample_weight)
#     605         Xt = X
#     606         for _, name, transform in self._iter(with_final=False):
# --> 607             Xt = transform.transform(Xt)
#     608         score_params = {}
#     609         if sample_weight is not None:
#
# ...
